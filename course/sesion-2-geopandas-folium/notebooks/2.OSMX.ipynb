# %%
import osmnx as ox

# %%
import geopandas as gpd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
#choosing area of interest
place = 'Barcelona'#Selecting amenities and extracting information
tags = {"amenity":"restaurant"}
restaurants = ox.features_from_place(place, tags=tags)

# %%
print(restaurants.shape)
# Out:
# (3260, 199)

# %%
type(restaurants)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
restaurants.columns.values
# Out:
# array(['amenity', 'name', 'name:ca', 'phone', 'geometry',
#        'check_date:opening_hours', 'opening_hours', 'cuisine',
#        'addr:city', 'addr:housenumber', 'addr:postcode', 'addr:street',
#        'diet:gluten_free', 'website', 'wheelchair', 'name:es', 'note',
#        'description', 'smoking', 'internet_access', 'name:tr',
#        'addr:floor', 'check_date', 'contact:phone', 'level',
#        'payment:credit_cards', 'toilets:wheelchair', 'addr:country',
#        'old_name', 'brand', 'brand:wikidata', 'brand:wikipedia',
#        'diet:vegetarian', 'name:en', 'entrance', 'alt_name', 'capacity',
#        'outdoor_seating', 'delivery', 'takeaway', 'email',
#        'internet_access:fee', 'reservation', 'indoor_seating',
#        'drink:club-mate', 'contact:email', 'contact:website',
#        'addr:housename', 'name:zh', 'wikidata', 'contact:facebook',
#        'contact:instagram', 'name:ru', 'wikipedia', 'name:ko',
#        'all_you_can_eat', 'website:reviews', 'diet:vegan', 'branch',
#        'operator', 'ref:vatin', 'fixme', 'fax', 'kids_area', 'toilets',
#        'toilets:access', 'source:date', 'wheelchair:description',
#        'source', 'microbrewery', 'payment:mastercard', 'payment:visa',
#        'addr:place', 'access:covid19', 'delivery:covid19',
#        'drive_through:covid19', 'opening_hours:covid19',
#        'takeaway:covid19', 'addr:state', 'contact:mobile', 'organic',
#        'air_conditioning', 'diet:halal', 'diet:kosher',
#        'payment:debit_cards', 'stars', 'survey:date', 'shop', 'brewery',
#        'drink:beer', 'contact:fax', 'internet_access:access',
#        'internet_access:password', 'internet_access:wlan:bssid',
#        'internet_access:wlan:channel', 'internet_access:wlan:enc',
#        'internet_access:wlan:essid', 'check_date:currency:XBT',
#        'currency:XBT', 'payment:coins', 'payment:lightning',
#        'payment:lightning_contactless', 'payment:onchain',
#        'internet_access:ssid', 'facebook', 'food', 'opening_hours:signed',
#        'payment:cash', 'opening_hours:kitchen', 'addr:province',
#        'nohousenumber', 'ref:catastral', 'url', 'opening_hours:url',
#        'description:en', 'diet:lactose_free', 'payment:jcb',
#        'payment:maestro', 'payment:v_pay', 'payment:visa_debit',
#        'payment:visa_electron', 'bar', 'payment:card', 'designation',
#        'name:he', 'diet:raw', 'name:et', 'name:it', 'addr:hamlet',
#        'name:ro', 'name:pt', 'payment:cards', 'service:electricity',
#        'name:ar', 'real_ale', 'name:de', 'addr:unit', 'amenity:2016',
#        'cuisine:2016', 'name:2016', 'GEOSPECIFI', 'IDADRESS',
#        'LOCATORDES', 'osm_type', 'TIPE', 'name:fr',
#        'payment:american_express', 'contact:twitter', 'drink:tea',
#        'name:sv', 'lunch', 'contact:whatsapp', 'name:ja', 'cocktails',
#        'not:brand:wikidata', 'diet:mediterranean', 'name:uk',
#        'payment:discover_card', 'payment:diners_club', 'drive_through',
#        'short_name', 'highchair', 'sorting_name', 'building',
#        'payment:contactless', 'payment:credit_card', 'dog', 'leisure',
#        'lgbtq', 'check_date:diet:vegetarian', 'access', 'changing_table',
#        'terrace', 'twitter', 'image', 'building:levels',
#        'building:levels:underground', 'diet:meat', 'diet:omnivore',
#        'diet:non-vegetarian', 'start_date', 'name:nl', 'diet:local',
#        'layer', 'diet:sugar_free', 'payment:edenred_card',
#        'payment:meal_voucher', 'fixme:type', 'mobile', 'nodes',
#        'name:etymology:wikidata', 'historic', 'area', 'amenity_1',
#        'building:part', 'building:material', 'height', 'ways', 'type'],
#       dtype=object)

# %%
restaurants
# Out:
#                             amenity                                name  \
# element_type osmid
# node         319840473   restaurant                             Amaltea
#              364731424   restaurant                           Hanibishi
#              364829711   restaurant                      Moncho's House
#              364838793   restaurant                     Taller de Tapas
#              365288417   restaurant              El Jardí de l'Abadessa
# ...                             ...                                 ...
# way          1081174565  restaurant                                 NaN
#              1161463975  restaurant  Bar del Club de Petanca El Carmelo
# relation     7936202     restaurant                    Asador de Aranda
#              8997108     restaurant                                 NaN
#              9070255     restaurant                       Els pescadors
#
#                                name:ca             phone  \
# element_type osmid
# node         319840473             NaN               NaN
#              364731424             NaN               NaN
#              364829711             NaN               NaN
#              364838793             NaN  +34 932 68 85 59
#              365288417             NaN               NaN
# ...                                ...               ...
# way          1081174565            NaN               NaN
#              1161463975            NaN      +34931383116
# relation     7936202               NaN  +34 934 17 01 15
#              8997108               NaN               NaN
#              9070255     Els pescadors  +34 93 225 20 18
#
#                                                                   geometry  \
# element_type osmid
# node         319840473                            POINT (2.15830 41.38364)
#              364731424                            POINT (2.16218 41.38952)
#              364829711                            POINT (2.13184 41.39000)
#              364838793                            POINT (2.18064 41.38367)
#              365288417                            POINT (2.10990 41.39423)
# ...                                                                    ...
# way          1081174565  POLYGON ((2.19091 41.37757, 2.19071 41.37753, ...
#              1161463975  POLYGON ((2.16407 41.42019, 2.16404 41.42009, ...
# relation     7936202     POLYGON ((2.13405 41.41341, 2.13422 41.41347, ...
#              8997108     POLYGON ((2.18705 41.37586, 2.18707 41.37595, ...
#              9070255     POLYGON ((2.20681 41.39958, 2.20696 41.39970, ...
#
#                         check_date:opening_hours  \
# element_type osmid
# node         319840473                2023-01-14
#              364731424                       NaN
#              364829711                       NaN
#              364838793                       NaN
#              365288417                       NaN
# ...                                          ...
# way          1081174565                      NaN
#              1161463975                      NaN
# relation     7936202                         NaN
#              8997108                         NaN
#              9070255                         NaN
#
#                                                 opening_hours   cuisine  \
# element_type osmid
# node         319840473      Mo-Su 13:00-16:00, Sa 20:00-23:00       NaN
#              364731424       PH,Mo-Su 13:00-16:30,19:00-23:30  japanese
#              364829711                                    NaN  regional
#              364838793   Su-Th 12:00-00:00; Fr-Sa 12:00-00:30   spanish
#              365288417                                    NaN       NaN
# ...                                                       ...       ...
# way          1081174565                                   NaN       NaN
#              1161463975                           09:00-00:00   spanish
# relation     7936202           Mo-Su 13:00-16:30, 20:00-23:30   spanish
#              8997108                                      NaN       NaN
#              9070255                                      NaN       NaN
#
#                          addr:city addr:housenumber  ...  \
# element_type osmid                                   ...
# node         319840473         NaN              NaN  ...
#              364731424         NaN              NaN  ...
#              364829711         NaN              NaN  ...
#              364838793   Barcelona               51  ...
#              365288417         NaN              NaN  ...
# ...                            ...              ...  ...
# way          1081174565        NaN              NaN  ...
#              1161463975        NaN               27  ...
# relation     7936202           NaN               31  ...
#              8997108           NaN              NaN  ...
#              9070255           NaN              NaN  ...
#
#                                                                      nodes  \
# element_type osmid
# node         319840473                                                 NaN
#              364731424                                                 NaN
#              364829711                                                 NaN
#              364838793                                                 NaN
#              365288417                                                 NaN
# ...                                                                    ...
# way          1081174565  [9909684480, 9909684481, 9909684482, 990968448...
#              1161463975  [10802655029, 10802655030, 10802655031, 108026...
# relation     7936202     [[[2333430368, 2333430347, 5363289946, 5363289...
#              8997108     [[[6074436595, 6074427534, 6074427526, 6074427...
#              9070255     [[[1356119783, 6110888414, 6110888425, 6110888...
#
#                         name:etymology:wikidata historic area amenity_1  \
# element_type osmid
# node         319840473                      NaN      NaN  NaN       NaN
#              364731424                      NaN      NaN  NaN       NaN
#              364829711                      NaN      NaN  NaN       NaN
#              364838793                      NaN      NaN  NaN       NaN
#              365288417                      NaN      NaN  NaN       NaN
# ...                                         ...      ...  ...       ...
# way          1081174565                     NaN      NaN  NaN       NaN
#              1161463975                     NaN      NaN  NaN       NaN
# relation     7936202                        NaN      NaN  NaN       NaN
#              8997108                        NaN      NaN  NaN       NaN
#              9070255                        NaN      NaN  NaN       NaN
#
#                         building:part building:material height  \
# element_type osmid
# node         319840473            NaN               NaN    NaN
#              364731424            NaN               NaN    NaN
#              364829711            NaN               NaN    NaN
#              364838793            NaN               NaN    NaN
#              365288417            NaN               NaN    NaN
# ...                               ...               ...    ...
# way          1081174565           NaN               NaN    NaN
#              1161463975           NaN               NaN    NaN
# relation     7936202              NaN               NaN    NaN
#              8997108              NaN               NaN    NaN
#              9070255              NaN               NaN    NaN
#
#                                                       ways          type
# element_type osmid
# node         319840473                                 NaN           NaN
#              364731424                                 NaN           NaN
#              364829711                                 NaN           NaN
#              364838793                                 NaN           NaN
#              365288417                                 NaN           NaN
# ...                                                    ...           ...
# way          1081174565                                NaN           NaN
#              1161463975                                NaN           NaN
# relation     7936202                [224522438, 555954290]  multipolygon
#              8997108                [646559065, 646559072]  multipolygon
#              9070255     [651707812, 651707814, 651707815]  multipolygon
#
# [3260 rows x 199 columns]

# %%
restaurants[['name', 'geometry']].plot()
# Out:
# <Axes: >
